# %%
from train_ogbn_arxiv import main
# Out:
# Using backend: pytorch
# WARNING:root:The OGB package is out of date. Your version is 1.3.2, while the latest version is 1.3.3.

# %%
class config:
    model = 'GTAN'
    n_hid = 128
    dropout = 0.2
    dropout2 = 0
    learning_rate = 0.01
    weight_decay = 5e-5
    num_iter = 1000
    num_test = 10
    hop = 4
    layerwise = True
    zero_init = True
    eval_metric = 'acc'
    log_steps = 100

args = config()

# %%
main(args)
# Out:
# #Parameters: 39208
# Run: 01, Time elapsed: 50.60, Epoch: 100, Loss: 0.9204, Train: 72.77%, Valid: 71.83% Test: 71.11%
# Run: 01, Time elapsed: 49.61, Epoch: 200, Loss: 0.8577, Train: 74.65%, Valid: 72.62% Test: 71.88%
# Run: 01, Time elapsed: 49.81, Epoch: 300, Loss: 0.8247, Train: 75.73%, Valid: 73.30% Test: 72.72%
# Run: 01, Time elapsed: 49.65, Epoch: 400, Loss: 0.8062, Train: 76.03%, Valid: 72.26% Test: 70.45%
# Run: 01, Time elapsed: 49.52, Epoch: 500, Loss: 0.7855, Train: 76.91%, Valid: 73.54% Test: 72.26%
# Run: 01, Time elapsed: 49.38, Epoch: 600, Loss: 0.7729, Train: 77.12%, Valid: 72.62% Test: 70.71%
# Run: 01, Time elapsed: 49.63, Epoch: 700, Loss: 0.7610, Train: 77.64%, Valid: 73.50% Test: 72.09%
# Run: 01, Time elapsed: 49.31, Epoch: 800, Loss: 0.7558, Train: 77.70%, Valid: 73.19% Test: 72.20%
# Run: 01, Time elapsed: 49.65, Epoch: 900, Loss: 0.7460, Train: 78.10%, Valid: 73.31% Test: 72.45%
# ...
