# %%
class config:
    data = 'Cora' #choices=["Cora", "Citeseer", "Pubmed", "Coauthor-CS"]
    model = 'GTAN' #choices=["GCN", "GAT", "APPNP", "DAGNN", "TreeLSTM", "GTCN", "GTAN", "GTCN2"]
    n_hid = 64
    dropout = 0.6
    dropout2 = 0.6
    learning_rate = 0.01
    weight_decay = 5e-4
    patience = 300
    num_iter = 1000
    num_test = 30
    hop = 5
    layerwise = True
    zero_init = False
    random_label_split = False
    num_train = 20 # for random label split only
    num_val = 30 # for random label split only
    data_load = True # load the saved label split to rerun the test (for reproduce purpose)
    test_id = 1 # number of the test, only used to record the ith number of the random label split (for reproduce purpose)
    filter_pct = 0.1 # remove the top and bottom filer_pct points before obtaining statistics of test accuracy
    log = False # whether to show the training log or not
    eval_metric = 'acc' # evaluation metrics, choices=["acc", "f1-macro", "f1-micro"]
    root_dir = '../..' # dir of the source code

args = config()

# %%
import sys
sys.path.append(args.root_dir)
from train import *
# Out:
# Using backend: pytorch

# %%
accs = []
datasets = ['Cora', 'Citeseer', 'Pubmed', 'Coauthor-CS']
for dataset in datasets:
    args.data = dataset
    if dataset == 'Cora':
        args.dropout = 0.6
        args.dropout2 = 0.6
        args.zero_init = False
        args.weight_decay = 5e-4
        print('\nstart testing on ' + dataset + ' dataset')
        accs.append(main(args))
    elif dataset == 'Citeseer':
        args.dropout = 0.6
        args.dropout2 = 0.6
        args.zero_init = True
        args.weight_decay = 5e-4
        print('\nstart testing on ' + dataset + ' dataset')
        accs.append(main(args))
    elif dataset == 'Pubmed':
        args.dropout = 0.6
        args.dropout2 = 0
        args.zero_init = False
        args.weight_decay = 5e-4
        print('\nstart testing on ' + dataset + ' dataset')
        accs.append(main(args))
    elif dataset == 'Coauthor-CS':
        args.dropout = 0.2
        args.dropout2 = 0.2
        args.weight_decay = 5e-3
        args.layerwise = False
        args.zero_init = True
        for i in [2]:
            print('\nstart testing on ' + dataset + ' dataset with random split: ' + str(i))
            args.test_id = i
            accs.append(main(args))
# Out:
# start testing on Cora dataset
#   NumNodes: 2708
#   NumEdges: 10556
#   NumFeats: 1433
#   NumClasses: 7
#   NumTrainingSamples: 140
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# time duration = 9.332, best val acc = 0.832, test acc = 0.839
# time duration = 7.285, best val acc = 0.838, test acc = 0.850
# time duration = 7.531, best val acc = 0.832, test acc = 0.842
# time duration = 7.240, best val acc = 0.818, test acc = 0.827
# time duration = 4.431, best val acc = 0.832, test acc = 0.841
# time duration = 8.694, best val acc = 0.832, test acc = 0.848
# time duration = 10.070, best val acc = 0.828, test acc = 0.852
# time duration = 5.282, best val acc = 0.822, test acc = 0.848
# time duration = 8.460, best val acc = 0.826, test acc = 0.850
# time duration = 4.256, best val acc = 0.814, test acc = 0.836
# time duration = 8.117, best val acc = 0.822, test acc = 0.842
# time duration = 13.137, best val acc = 0.818, test acc = 0.847
# time duration = 9.040, best val acc = 0.822, test acc = 0.839
# time duration = 5.492, best val acc = 0.832, test acc = 0.851
# time duration = 12.886, best val acc = 0.836, test acc = 0.843
# time duration = 7.257, best val acc = 0.844, test acc = 0.862
# time duration = 5.499, best val acc = 0.822, test acc = 0.838
# time duration = 5.300, best val acc = 0.822, test acc = 0.841
# time duration = 4.852, best val acc = 0.812, test acc = 0.828
# time duration = 4.613, best val acc = 0.798, test acc = 0.818
# time duration = 4.953, best val acc = 0.822, test acc = 0.846
# time duration = 8.370, best val acc = 0.828, test acc = 0.844
# time duration = 7.041, best val acc = 0.826, test acc = 0.844
# time duration = 5.293, best val acc = 0.832, test acc = 0.845
# time duration = 5.623, best val acc = 0.824, test acc = 0.852
# time duration = 7.413, best val acc = 0.832, test acc = 0.850
# time duration = 6.117, best val acc = 0.824, test acc = 0.847
# time duration = 5.064, best val acc = 0.814, test acc = 0.817
# time duration = 5.559, best val acc = 0.828, test acc = 0.826
# time duration = 8.753, best val acc = 0.836, test acc = 0.846
# test acc (mean, std):  0.8419667065143586 0.009991609900231008
# test acc (mean, std) after filter:  0.8430000394582748 0.006171165332181153
#
# start testing on Citeseer dataset
#   NumNodes: 3327
#   NumEdges: 9228
#   NumFeats: 3703
#   NumClasses: 6
#   NumTrainingSamples: 120
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# time duration = 4.512, best val acc = 0.738, test acc = 0.720
# time duration = 4.616, best val acc = 0.722, test acc = 0.691
# time duration = 4.358, best val acc = 0.728, test acc = 0.696
# time duration = 4.421, best val acc = 0.732, test acc = 0.704
# time duration = 4.981, best val acc = 0.738, test acc = 0.718
# time duration = 4.332, best val acc = 0.738, test acc = 0.728
# time duration = 4.178, best val acc = 0.726, test acc = 0.714
# time duration = 4.488, best val acc = 0.740, test acc = 0.732
# time duration = 4.506, best val acc = 0.740, test acc = 0.739
# time duration = 4.296, best val acc = 0.734, test acc = 0.723
# time duration = 7.368, best val acc = 0.736, test acc = 0.723
# time duration = 4.516, best val acc = 0.742, test acc = 0.730
# time duration = 6.600, best val acc = 0.726, test acc = 0.717
# time duration = 6.700, best val acc = 0.738, test acc = 0.717
# time duration = 6.009, best val acc = 0.728, test acc = 0.717
# time duration = 4.253, best val acc = 0.740, test acc = 0.732
# time duration = 4.923, best val acc = 0.736, test acc = 0.710
# time duration = 4.397, best val acc = 0.732, test acc = 0.717
# time duration = 5.960, best val acc = 0.736, test acc = 0.708
# time duration = 6.664, best val acc = 0.736, test acc = 0.721
# time duration = 4.231, best val acc = 0.738, test acc = 0.726
# time duration = 4.706, best val acc = 0.732, test acc = 0.729
# time duration = 4.202, best val acc = 0.732, test acc = 0.727
# time duration = 4.471, best val acc = 0.742, test acc = 0.736
# time duration = 6.381, best val acc = 0.736, test acc = 0.713
# time duration = 4.570, best val acc = 0.746, test acc = 0.736
# time duration = 4.517, best val acc = 0.742, test acc = 0.728
# time duration = 4.285, best val acc = 0.740, test acc = 0.722
# time duration = 6.746, best val acc = 0.734, test acc = 0.717
# time duration = 4.259, best val acc = 0.718, test acc = 0.696
# test acc (mean, std):  0.7195667028427124 0.011831269670555738
# test acc (mean, std) after filter:  0.720541700720787 0.007449719555180221
#
# start testing on Pubmed dataset
#   NumNodes: 19717
#   NumEdges: 88651
#   NumFeats: 500
#   NumClasses: 3
#   NumTrainingSamples: 60
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# time duration = 9.284, best val acc = 0.818, test acc = 0.799
# time duration = 8.303, best val acc = 0.828, test acc = 0.798
# time duration = 13.386, best val acc = 0.818, test acc = 0.793
# time duration = 9.872, best val acc = 0.818, test acc = 0.791
# time duration = 9.874, best val acc = 0.816, test acc = 0.780
# time duration = 7.397, best val acc = 0.814, test acc = 0.800
# time duration = 11.347, best val acc = 0.822, test acc = 0.798
# time duration = 10.115, best val acc = 0.820, test acc = 0.796
# time duration = 9.994, best val acc = 0.822, test acc = 0.805
# time duration = 10.793, best val acc = 0.824, test acc = 0.805
# time duration = 7.511, best val acc = 0.810, test acc = 0.793
# time duration = 7.702, best val acc = 0.822, test acc = 0.797
# time duration = 9.462, best val acc = 0.816, test acc = 0.797
# time duration = 7.917, best val acc = 0.816, test acc = 0.786
# time duration = 7.523, best val acc = 0.816, test acc = 0.791
# time duration = 11.592, best val acc = 0.816, test acc = 0.784
# time duration = 7.467, best val acc = 0.818, test acc = 0.783
# time duration = 10.603, best val acc = 0.828, test acc = 0.792
# time duration = 7.812, best val acc = 0.826, test acc = 0.797
# time duration = 10.362, best val acc = 0.824, test acc = 0.790
# time duration = 11.425, best val acc = 0.820, test acc = 0.777
# time duration = 16.069, best val acc = 0.816, test acc = 0.784
# time duration = 8.775, best val acc = 0.826, test acc = 0.800
# time duration = 9.953, best val acc = 0.826, test acc = 0.797
# time duration = 9.822, best val acc = 0.822, test acc = 0.795
# time duration = 10.290, best val acc = 0.814, test acc = 0.784
# time duration = 13.005, best val acc = 0.818, test acc = 0.778
# time duration = 7.701, best val acc = 0.820, test acc = 0.795
# time duration = 9.512, best val acc = 0.814, test acc = 0.799
# time duration = 8.183, best val acc = 0.816, test acc = 0.788
# test acc (mean, std):  0.7924000362555186 0.007445807269271563
# test acc (mean, std) after filter:  0.7927917018532753 0.005346175479141472
#
# start testing on Coauthor-CS dataset with random split: 2
# time duration = 14.831, best val acc = 0.913, test acc = 0.917
# time duration = 13.098, best val acc = 0.902, test acc = 0.916
# time duration = 12.720, best val acc = 0.911, test acc = 0.915
# time duration = 13.602, best val acc = 0.916, test acc = 0.918
# time duration = 13.406, best val acc = 0.907, test acc = 0.916
# time duration = 18.970, best val acc = 0.920, test acc = 0.922
# time duration = 12.765, best val acc = 0.907, test acc = 0.914
# time duration = 12.811, best val acc = 0.911, test acc = 0.917
# time duration = 19.277, best val acc = 0.909, test acc = 0.917
# time duration = 12.786, best val acc = 0.911, test acc = 0.910
# time duration = 13.040, best val acc = 0.907, test acc = 0.922
# time duration = 24.558, best val acc = 0.918, test acc = 0.916
# time duration = 15.495, best val acc = 0.911, test acc = 0.919
# time duration = 27.822, best val acc = 0.916, test acc = 0.919
# time duration = 20.275, best val acc = 0.916, test acc = 0.920
# time duration = 19.976, best val acc = 0.918, test acc = 0.914
# time duration = 12.966, best val acc = 0.913, test acc = 0.913
# time duration = 16.898, best val acc = 0.920, test acc = 0.913
# time duration = 15.825, best val acc = 0.911, test acc = 0.914
# time duration = 12.983, best val acc = 0.916, test acc = 0.918
# time duration = 21.663, best val acc = 0.918, test acc = 0.920
# time duration = 14.317, best val acc = 0.909, test acc = 0.922
# time duration = 13.400, best val acc = 0.907, test acc = 0.916
# time duration = 14.014, best val acc = 0.913, test acc = 0.919
# time duration = 18.207, best val acc = 0.918, test acc = 0.920
# time duration = 13.919, best val acc = 0.911, test acc = 0.911
# time duration = 14.792, best val acc = 0.916, test acc = 0.919
# time duration = 14.018, best val acc = 0.907, test acc = 0.914
# time duration = 12.646, best val acc = 0.911, test acc = 0.921
# time duration = 15.795, best val acc = 0.918, test acc = 0.924
# test acc (mean, std):  0.9172041098276774 0.003361983912637138
# test acc (mean, std) after filter:  0.9172567203640938 0.002347775166253072

# %%
accs = np.array(accs)
