# %%
class config:
    data = 'Cora' #choices=["Cora", "Citeseer", "Pubmed", "Coauthor-CS"]
    model = 'GTAN' #choices=["GCN", "GAT", "APPNP", "DAGNN", "TreeLSTM", "GTCN", "GTAN", "GTCN2"]
    n_hid = 64
    dropout = 0.6
    dropout2 = 0
    learning_rate = 0.01
    weight_decay = 5e-4
    patience = 300
    num_iter = 1000
    num_test = 30
    hop = 10
    layerwise = True
    zero_init = False
    random_label_split = False
    num_train = 20 # for random label split only
    num_val = 30 # for random label split only
    data_load = True # load the saved label split to rerun the test (for reproduce purpose)
    test_id = 1 # number of the test, only used to record the ith number of the random label split (for reproduce purpose)
    filter_pct = 0.1 # remove the top and bottom filer_pct points before obtaining statistics of test accuracy
    log = False # whether to show the training log or not
    eval_metric = 'acc' # evaluation metrics, choices=["acc", "f1-macro", "f1-micro"]
    root_dir = '../..' # dir of the source code

args = config()

# %%
import sys
sys.path.append(args.root_dir)
from train import *
# Out:
# Using backend: pytorch

# %%
accs = []
datasets = ['Cora', 'Citeseer', 'Pubmed', 'Coauthor-CS']
for dataset in datasets:
    args.data = dataset
    if dataset == 'Cora':
        args.dropout = 0.6
        args.dropout2 = 0
        args.zero_init = False
        args.weight_decay = 5e-4
        print('\nstart testing on ' + dataset + ' dataset')
        accs.append(main(args))
    elif dataset == 'Citeseer':
        args.dropout = 0.6
        args.dropout2 = 0.6
        args.zero_init = True
        args.weight_decay = 5e-4
        print('\nstart testing on ' + dataset + ' dataset')
        accs.append(main(args))
    elif dataset == 'Pubmed':
        args.dropout = 0.6
        args.dropout2 = 0
        args.zero_init = False
        args.weight_decay = 5e-4
        print('\nstart testing on ' + dataset + ' dataset')
        accs.append(main(args))
    elif dataset == 'Coauthor-CS':
        args.dropout = 0.2
        args.dropout2 = 0.2
        args.weight_decay = 5e-3
        args.layerwise = False
        args.zero_init = True
        for i in range(3):
            print('\nstart testing on ' + dataset + ' dataset with random split: ' + str(i))
            args.test_id = i
            accs.append(main(args))
# Out:
# start testing on Cora dataset
#   NumNodes: 2708
#   NumEdges: 10556
#   NumFeats: 1433
#   NumClasses: 7
#   NumTrainingSamples: 140
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# time duration = 18.429, best val acc = 0.818, test acc = 0.843
# time duration = 10.650, best val acc = 0.818, test acc = 0.842
# time duration = 14.645, best val acc = 0.814, test acc = 0.837
# time duration = 10.390, best val acc = 0.814, test acc = 0.837
# time duration = 9.962, best val acc = 0.812, test acc = 0.827
# time duration = 14.819, best val acc = 0.814, test acc = 0.831
# time duration = 11.453, best val acc = 0.818, test acc = 0.841
# time duration = 23.469, best val acc = 0.818, test acc = 0.837
# time duration = 10.057, best val acc = 0.818, test acc = 0.841
# time duration = 8.120, best val acc = 0.812, test acc = 0.839
# time duration = 9.131, best val acc = 0.822, test acc = 0.846
# time duration = 21.571, best val acc = 0.822, test acc = 0.845
# time duration = 19.187, best val acc = 0.822, test acc = 0.830
# time duration = 11.636, best val acc = 0.824, test acc = 0.845
# time duration = 8.204, best val acc = 0.822, test acc = 0.832
# time duration = 8.814, best val acc = 0.810, test acc = 0.819
# time duration = 10.293, best val acc = 0.820, test acc = 0.826
# time duration = 7.836, best val acc = 0.820, test acc = 0.826
# time duration = 12.706, best val acc = 0.816, test acc = 0.844
# time duration = 15.969, best val acc = 0.820, test acc = 0.838
# time duration = 10.094, best val acc = 0.818, test acc = 0.824
# time duration = 11.145, best val acc = 0.814, test acc = 0.842
# time duration = 15.729, best val acc = 0.814, test acc = 0.836
# time duration = 9.774, best val acc = 0.820, test acc = 0.847
# time duration = 11.617, best val acc = 0.820, test acc = 0.843
# time duration = 23.276, best val acc = 0.824, test acc = 0.838
# time duration = 15.657, best val acc = 0.816, test acc = 0.842
# time duration = 19.981, best val acc = 0.820, test acc = 0.840
# time duration = 7.407, best val acc = 0.818, test acc = 0.827
# time duration = 11.234, best val acc = 0.826, test acc = 0.836
# test acc (mean, std):  0.8367000381151836 0.007294519443042441
# test acc (mean, std) after filter:  0.8372500364979109 0.005547153905594026
#
# start testing on Citeseer dataset
#   NumNodes: 3327
#   NumEdges: 9228
#   NumFeats: 3703
#   NumClasses: 6
#   NumTrainingSamples: 120
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# time duration = 11.362, best val acc = 0.726, test acc = 0.704
# time duration = 8.606, best val acc = 0.728, test acc = 0.733
# time duration = 8.407, best val acc = 0.736, test acc = 0.739
# time duration = 8.187, best val acc = 0.738, test acc = 0.724
# time duration = 8.829, best val acc = 0.736, test acc = 0.724
# time duration = 8.395, best val acc = 0.730, test acc = 0.723
# time duration = 7.599, best val acc = 0.734, test acc = 0.708
# time duration = 9.071, best val acc = 0.734, test acc = 0.730
# time duration = 7.848, best val acc = 0.730, test acc = 0.710
# time duration = 8.107, best val acc = 0.722, test acc = 0.703
# time duration = 7.811, best val acc = 0.734, test acc = 0.725
# time duration = 8.009, best val acc = 0.736, test acc = 0.724
# time duration = 8.173, best val acc = 0.748, test acc = 0.731
# time duration = 7.971, best val acc = 0.730, test acc = 0.732
# time duration = 8.184, best val acc = 0.730, test acc = 0.724
# time duration = 11.675, best val acc = 0.732, test acc = 0.706
# time duration = 7.468, best val acc = 0.738, test acc = 0.709
# time duration = 8.034, best val acc = 0.736, test acc = 0.719
# time duration = 8.258, best val acc = 0.738, test acc = 0.725
# time duration = 7.722, best val acc = 0.744, test acc = 0.735
# time duration = 14.765, best val acc = 0.730, test acc = 0.713
# time duration = 8.181, best val acc = 0.730, test acc = 0.719
# time duration = 7.421, best val acc = 0.728, test acc = 0.720
# time duration = 7.912, best val acc = 0.746, test acc = 0.722
# time duration = 7.552, best val acc = 0.740, test acc = 0.725
# time duration = 9.733, best val acc = 0.726, test acc = 0.716
# time duration = 7.437, best val acc = 0.736, test acc = 0.734
# time duration = 7.400, best val acc = 0.756, test acc = 0.728
# time duration = 7.615, best val acc = 0.736, test acc = 0.733
# time duration = 8.202, best val acc = 0.732, test acc = 0.745
# test acc (mean, std):  0.7227667013804118 0.010439296128493567
# test acc (mean, std) after filter:  0.7229583685596784 0.007463684221439194
#
# start testing on Pubmed dataset
#   NumNodes: 19717
#   NumEdges: 88651
#   NumFeats: 500
#   NumClasses: 3
#   NumTrainingSamples: 60
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# time duration = 14.441, best val acc = 0.818, test acc = 0.794
# time duration = 22.300, best val acc = 0.824, test acc = 0.798
# time duration = 20.735, best val acc = 0.820, test acc = 0.787
# time duration = 13.945, best val acc = 0.818, test acc = 0.789
# time duration = 15.801, best val acc = 0.824, test acc = 0.801
# time duration = 16.597, best val acc = 0.826, test acc = 0.803
# time duration = 14.715, best val acc = 0.820, test acc = 0.788
# time duration = 15.588, best val acc = 0.820, test acc = 0.796
# time duration = 16.316, best val acc = 0.824, test acc = 0.800
# time duration = 15.694, best val acc = 0.822, test acc = 0.798
# time duration = 15.041, best val acc = 0.820, test acc = 0.796
# time duration = 26.454, best val acc = 0.818, test acc = 0.801
# time duration = 13.917, best val acc = 0.816, test acc = 0.792
# time duration = 14.694, best val acc = 0.820, test acc = 0.791
# time duration = 15.391, best val acc = 0.826, test acc = 0.801
# time duration = 18.602, best val acc = 0.812, test acc = 0.794
# time duration = 20.621, best val acc = 0.836, test acc = 0.798
# time duration = 16.749, best val acc = 0.820, test acc = 0.795
# time duration = 14.411, best val acc = 0.814, test acc = 0.791
# time duration = 17.463, best val acc = 0.824, test acc = 0.798
# time duration = 14.143, best val acc = 0.818, test acc = 0.792
# time duration = 13.928, best val acc = 0.816, test acc = 0.795
# time duration = 16.546, best val acc = 0.820, test acc = 0.797
# time duration = 15.971, best val acc = 0.816, test acc = 0.796
# time duration = 14.884, best val acc = 0.822, test acc = 0.795
# time duration = 21.449, best val acc = 0.824, test acc = 0.802
# time duration = 16.159, best val acc = 0.820, test acc = 0.805
# time duration = 15.965, best val acc = 0.822, test acc = 0.804
# time duration = 16.381, best val acc = 0.824, test acc = 0.795
# time duration = 14.135, best val acc = 0.820, test acc = 0.782
# test acc (mean, std):  0.7958000401655833 0.005230678773001911
# test acc (mean, std) after filter:  0.7960417047142982 0.0034578380644706627
#
# start testing on Coauthor-CS dataset with random split: 0
# time duration = 36.513, best val acc = 0.918, test acc = 0.926
# time duration = 20.488, best val acc = 0.904, test acc = 0.921
# time duration = 20.488, best val acc = 0.902, test acc = 0.922
# time duration = 22.764, best val acc = 0.911, test acc = 0.915
# time duration = 26.790, best val acc = 0.916, test acc = 0.922
# time duration = 22.948, best val acc = 0.911, test acc = 0.926
# time duration = 41.710, best val acc = 0.916, test acc = 0.929
# time duration = 20.934, best val acc = 0.909, test acc = 0.922
# time duration = 21.338, best val acc = 0.907, test acc = 0.922
# time duration = 20.610, best val acc = 0.904, test acc = 0.925
# time duration = 20.532, best val acc = 0.898, test acc = 0.922
# time duration = 21.478, best val acc = 0.918, test acc = 0.919
# time duration = 20.168, best val acc = 0.904, test acc = 0.920
# time duration = 21.005, best val acc = 0.911, test acc = 0.922
# time duration = 20.433, best val acc = 0.907, test acc = 0.925
# time duration = 21.594, best val acc = 0.902, test acc = 0.911
# time duration = 20.393, best val acc = 0.916, test acc = 0.923
# time duration = 20.545, best val acc = 0.920, test acc = 0.924
# time duration = 25.332, best val acc = 0.920, test acc = 0.925
# time duration = 21.018, best val acc = 0.907, test acc = 0.927
# time duration = 20.295, best val acc = 0.900, test acc = 0.921
# time duration = 23.550, best val acc = 0.924, test acc = 0.928
# time duration = 37.030, best val acc = 0.909, test acc = 0.921
# time duration = 34.136, best val acc = 0.911, test acc = 0.921
# time duration = 22.499, best val acc = 0.918, test acc = 0.923
# time duration = 20.552, best val acc = 0.907, test acc = 0.924
# time duration = 20.472, best val acc = 0.902, test acc = 0.923
# time duration = 40.877, best val acc = 0.918, test acc = 0.920
# time duration = 30.506, best val acc = 0.913, test acc = 0.924
# time duration = 19.962, best val acc = 0.891, test acc = 0.915
# test acc (mean, std):  0.9222260097662608 0.003788018837187199
# test acc (mean, std) after filter:  0.9226217518250147 0.0018301272523592457
#
# start testing on Coauthor-CS dataset with random split: 1
# time duration = 20.658, best val acc = 0.924, test acc = 0.914
# time duration = 20.933, best val acc = 0.938, test acc = 0.927
# time duration = 27.103, best val acc = 0.938, test acc = 0.928
# time duration = 23.738, best val acc = 0.936, test acc = 0.918
# time duration = 24.637, best val acc = 0.936, test acc = 0.925
# time duration = 44.878, best val acc = 0.944, test acc = 0.933
# time duration = 43.217, best val acc = 0.949, test acc = 0.932
# time duration = 20.533, best val acc = 0.936, test acc = 0.926
# time duration = 20.606, best val acc = 0.940, test acc = 0.925
# time duration = 26.304, best val acc = 0.936, test acc = 0.920
# time duration = 65.034, best val acc = 0.947, test acc = 0.927
# time duration = 20.793, best val acc = 0.933, test acc = 0.927
# time duration = 25.517, best val acc = 0.944, test acc = 0.927
# time duration = 33.390, best val acc = 0.942, test acc = 0.929
# time duration = 30.088, best val acc = 0.940, test acc = 0.921
# time duration = 37.101, best val acc = 0.940, test acc = 0.924
# time duration = 20.159, best val acc = 0.940, test acc = 0.916
# time duration = 23.778, best val acc = 0.938, test acc = 0.927
# time duration = 20.272, best val acc = 0.940, test acc = 0.921
# time duration = 20.737, best val acc = 0.936, test acc = 0.925
# time duration = 20.668, best val acc = 0.938, test acc = 0.923
# time duration = 41.359, best val acc = 0.944, test acc = 0.930
# time duration = 43.332, best val acc = 0.947, test acc = 0.927
# time duration = 23.598, best val acc = 0.933, test acc = 0.914
# time duration = 20.992, best val acc = 0.927, test acc = 0.920
# time duration = 21.689, best val acc = 0.929, test acc = 0.928
# time duration = 27.360, best val acc = 0.940, test acc = 0.923
# time duration = 20.932, best val acc = 0.931, test acc = 0.923
# time duration = 20.291, best val acc = 0.938, test acc = 0.926
# time duration = 20.350, best val acc = 0.940, test acc = 0.927
# test acc (mean, std):  0.9243549585342408 0.004670701681589046
# test acc (mean, std) after filter:  0.9247189462184906 0.002940330835633445
#
# start testing on Coauthor-CS dataset with random split: 2
# time duration = 20.218, best val acc = 0.913, test acc = 0.917
# time duration = 20.912, best val acc = 0.918, test acc = 0.925
# time duration = 24.332, best val acc = 0.911, test acc = 0.921
# time duration = 20.413, best val acc = 0.909, test acc = 0.918
# time duration = 22.567, best val acc = 0.896, test acc = 0.916
# time duration = 25.869, best val acc = 0.918, test acc = 0.924
# time duration = 39.282, best val acc = 0.916, test acc = 0.919
# time duration = 49.455, best val acc = 0.918, test acc = 0.925
# time duration = 20.740, best val acc = 0.907, test acc = 0.922
# time duration = 24.039, best val acc = 0.909, test acc = 0.917
# time duration = 20.877, best val acc = 0.920, test acc = 0.924
# time duration = 20.858, best val acc = 0.913, test acc = 0.912
# time duration = 21.498, best val acc = 0.909, test acc = 0.918
# time duration = 34.973, best val acc = 0.916, test acc = 0.916
# time duration = 45.430, best val acc = 0.924, test acc = 0.924
# time duration = 23.074, best val acc = 0.916, test acc = 0.917
# time duration = 20.683, best val acc = 0.911, test acc = 0.918
# time duration = 23.400, best val acc = 0.904, test acc = 0.917
# time duration = 20.892, best val acc = 0.907, test acc = 0.915
# time duration = 28.367, best val acc = 0.909, test acc = 0.920
# time duration = 20.632, best val acc = 0.902, test acc = 0.917
# time duration = 22.051, best val acc = 0.918, test acc = 0.923
# time duration = 22.843, best val acc = 0.913, test acc = 0.917
# time duration = 20.945, best val acc = 0.907, test acc = 0.921
# time duration = 29.483, best val acc = 0.916, test acc = 0.925
# time duration = 26.279, best val acc = 0.920, test acc = 0.923
# time duration = 20.772, best val acc = 0.916, test acc = 0.923
# time duration = 19.962, best val acc = 0.911, test acc = 0.900
# time duration = 23.081, best val acc = 0.911, test acc = 0.923
# time duration = 22.479, best val acc = 0.920, test acc = 0.920
# test acc (mean, std):  0.9191965659459432 0.00496932952677206
# test acc (mean, std) after filter:  0.9197543958822886 0.0027982959194861787

# %%
accs = np.array(accs)
