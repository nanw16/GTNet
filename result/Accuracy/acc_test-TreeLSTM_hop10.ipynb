# %%
class config:
    data = 'Cora' #choices=["Cora", "Citeseer", "Pubmed", "Coauthor-CS"]
    model = 'TreeLSTM' #choices=["GCN", "GAT", "APPNP", "DAGNN", "TreeLSTM", "GTCN", "GTAN", "GTCN2"]
    n_in = 0
    n_hid = 64
    n_out = 0
    num_heads = 1
    num_out_heads = 1
    device = 'cpu'
    dropout = 0.8
    dropout2 = 0.6
    learning_rate = 0.01
    weight_decay = 5e-4
    patience = 200
    num_iter = 1000
    num_test = 30
    hop = 10
    alpha = 0.1 # used by APPNP only
    random_label_split = False
    num_train = 20 # for random label split only
    num_val = 30 # for random label split only
    data_load = True # load the saved label split to rerun the test (for reproduce purpose)
    test_id = 1 # number of the test, only used to record the ith number of the random label split (for reproduce purpose)
    filter_pct = 0.1 # remove the top and bottom filer_pct points before obtaining statistics of test accuracy
    log = False # whether to show the training log or not
    eval_metric = 'acc' # evaluation metrics, choices=["acc", "f1-macro", "f1-micro"]
    root_dir = '../..' # dir of the source code

args = config()

# %%
import sys
sys.path.append(args.root_dir)
from train import *
# Out:
# Using backend: pytorch

# %%
accs = []
datasets = ['Cora', 'Citeseer', 'Pubmed', 'Coauthor-CS']
for dataset in datasets:
    args.data = dataset
    if dataset == 'Cora':
        print('\nstart testing on ' + dataset + ' dataset')
        accs.append(main(args))
    elif dataset == 'Citeseer':
        print('\nstart testing on ' + dataset + ' dataset')
        accs.append(main(args))
    elif dataset == 'Pubmed':
        print('\nstart testing on ' + dataset + ' dataset')
        accs.append(main(args))
    elif dataset == 'Coauthor-CS':
        for i in [2]:
            print('\nstart testing on ' + dataset + ' dataset with random split: ' + str(i))
            args.test_id = i
            accs.append(main(args))
# Out:
# start testing on Cora dataset
#   NumNodes: 2708
#   NumEdges: 10556
#   NumFeats: 1433
#   NumClasses: 7
#   NumTrainingSamples: 140
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# time duration = 8.404, best val acc = 0.808, test acc = 0.810
# time duration = 7.608, best val acc = 0.796, test acc = 0.800
# time duration = 13.127, best val acc = 0.812, test acc = 0.812
# time duration = 8.705, best val acc = 0.790, test acc = 0.792
# time duration = 7.654, best val acc = 0.798, test acc = 0.801
# time duration = 8.097, best val acc = 0.804, test acc = 0.801
# time duration = 10.969, best val acc = 0.796, test acc = 0.804
# time duration = 8.773, best val acc = 0.810, test acc = 0.802
# time duration = 15.788, best val acc = 0.812, test acc = 0.815
# time duration = 14.197, best val acc = 0.796, test acc = 0.797
# time duration = 8.146, best val acc = 0.802, test acc = 0.800
# time duration = 6.886, best val acc = 0.814, test acc = 0.804
# time duration = 7.443, best val acc = 0.804, test acc = 0.800
# time duration = 6.778, best val acc = 0.800, test acc = 0.796
# time duration = 12.587, best val acc = 0.806, test acc = 0.804
# time duration = 8.047, best val acc = 0.802, test acc = 0.813
# time duration = 13.820, best val acc = 0.812, test acc = 0.791
# time duration = 12.267, best val acc = 0.804, test acc = 0.792
# time duration = 11.617, best val acc = 0.806, test acc = 0.808
# time duration = 10.089, best val acc = 0.816, test acc = 0.806
# time duration = 18.351, best val acc = 0.802, test acc = 0.815
# time duration = 7.837, best val acc = 0.798, test acc = 0.812
# time duration = 7.862, best val acc = 0.802, test acc = 0.794
# time duration = 12.359, best val acc = 0.810, test acc = 0.823
# time duration = 10.210, best val acc = 0.782, test acc = 0.798
# time duration = 10.899, best val acc = 0.808, test acc = 0.813
# time duration = 8.911, best val acc = 0.804, test acc = 0.811
# time duration = 7.251, best val acc = 0.806, test acc = 0.814
# time duration = 7.315, best val acc = 0.802, test acc = 0.789
# time duration = 14.661, best val acc = 0.814, test acc = 0.794
# test acc (mean, std):  0.8037000358104706 0.008556282939731827
# test acc (mean, std) after filter:  0.8035833686590195 0.006626437784443432
#
# start testing on Citeseer dataset
#   NumNodes: 3327
#   NumEdges: 9228
#   NumFeats: 3703
#   NumClasses: 6
#   NumTrainingSamples: 120
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# time duration = 9.052, best val acc = 0.680, test acc = 0.671
# time duration = 9.278, best val acc = 0.660, test acc = 0.652
# time duration = 10.049, best val acc = 0.662, test acc = 0.659
# time duration = 15.892, best val acc = 0.654, test acc = 0.627
# time duration = 12.207, best val acc = 0.674, test acc = 0.645
# time duration = 9.214, best val acc = 0.648, test acc = 0.630
# time duration = 9.156, best val acc = 0.702, test acc = 0.672
# time duration = 10.440, best val acc = 0.648, test acc = 0.637
# time duration = 9.089, best val acc = 0.652, test acc = 0.637
# time duration = 11.351, best val acc = 0.656, test acc = 0.646
# time duration = 8.601, best val acc = 0.674, test acc = 0.654
# time duration = 8.939, best val acc = 0.638, test acc = 0.630
# time duration = 21.195, best val acc = 0.672, test acc = 0.663
# time duration = 16.674, best val acc = 0.650, test acc = 0.635
# time duration = 18.551, best val acc = 0.670, test acc = 0.644
# time duration = 10.539, best val acc = 0.652, test acc = 0.659
# time duration = 8.985, best val acc = 0.670, test acc = 0.664
# time duration = 13.781, best val acc = 0.660, test acc = 0.627
# time duration = 11.391, best val acc = 0.658, test acc = 0.629
# time duration = 9.003, best val acc = 0.642, test acc = 0.642
# time duration = 9.010, best val acc = 0.666, test acc = 0.655
# time duration = 9.400, best val acc = 0.668, test acc = 0.662
# time duration = 10.947, best val acc = 0.672, test acc = 0.645
# time duration = 9.513, best val acc = 0.646, test acc = 0.619
# time duration = 8.706, best val acc = 0.638, test acc = 0.612
# time duration = 9.250, best val acc = 0.656, test acc = 0.643
# time duration = 9.477, best val acc = 0.668, test acc = 0.646
# time duration = 17.481, best val acc = 0.654, test acc = 0.652
# time duration = 9.338, best val acc = 0.664, test acc = 0.671
# time duration = 13.812, best val acc = 0.664, test acc = 0.666
# test acc (mean, std):  0.6464666982491811 0.015774942469513723
# test acc (mean, std) after filter:  0.6467500329017639 0.011702029444752675
#
# start testing on Pubmed dataset
#   NumNodes: 19717
#   NumEdges: 88651
#   NumFeats: 500
#   NumClasses: 3
#   NumTrainingSamples: 60
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# time duration = 11.775, best val acc = 0.792, test acc = 0.768
# time duration = 20.366, best val acc = 0.802, test acc = 0.770
# time duration = 14.457, best val acc = 0.802, test acc = 0.779
# time duration = 16.622, best val acc = 0.802, test acc = 0.777
# time duration = 14.190, best val acc = 0.800, test acc = 0.765
# time duration = 13.986, best val acc = 0.802, test acc = 0.773
# time duration = 11.669, best val acc = 0.802, test acc = 0.774
# time duration = 12.502, best val acc = 0.788, test acc = 0.764
# time duration = 12.159, best val acc = 0.794, test acc = 0.753
# time duration = 17.789, best val acc = 0.806, test acc = 0.776
# time duration = 16.780, best val acc = 0.804, test acc = 0.778
# time duration = 13.625, best val acc = 0.792, test acc = 0.780
# time duration = 14.042, best val acc = 0.802, test acc = 0.772
# time duration = 13.578, best val acc = 0.796, test acc = 0.768
# time duration = 26.214, best val acc = 0.794, test acc = 0.771
# time duration = 15.675, best val acc = 0.808, test acc = 0.780
# time duration = 13.623, best val acc = 0.792, test acc = 0.776
# time duration = 15.803, best val acc = 0.796, test acc = 0.776
# time duration = 11.989, best val acc = 0.794, test acc = 0.778
# time duration = 15.876, best val acc = 0.798, test acc = 0.781
# time duration = 15.253, best val acc = 0.802, test acc = 0.762
# time duration = 14.253, best val acc = 0.804, test acc = 0.774
# time duration = 12.210, best val acc = 0.800, test acc = 0.773
# time duration = 26.208, best val acc = 0.798, test acc = 0.782
# time duration = 20.747, best val acc = 0.786, test acc = 0.754
# time duration = 12.825, best val acc = 0.808, test acc = 0.774
# time duration = 16.231, best val acc = 0.810, test acc = 0.786
# time duration = 19.143, best val acc = 0.802, test acc = 0.773
# time duration = 24.421, best val acc = 0.798, test acc = 0.769
# time duration = 11.727, best val acc = 0.802, test acc = 0.761
# test acc (mean, std):  0.772233368953069 0.007697116628141395
# test acc (mean, std) after filter:  0.772916704416275 0.0048982715758060895
#
# start testing on Coauthor-CS dataset with random split: 2
# time duration = 38.025, best val acc = 0.900, test acc = 0.913
# time duration = 36.457, best val acc = 0.898, test acc = 0.897
# time duration = 50.596, best val acc = 0.893, test acc = 0.909
# time duration = 46.309, best val acc = 0.900, test acc = 0.913
# time duration = 38.256, best val acc = 0.900, test acc = 0.912
# time duration = 47.225, best val acc = 0.898, test acc = 0.905
# time duration = 40.101, best val acc = 0.900, test acc = 0.911
# time duration = 46.377, best val acc = 0.900, test acc = 0.907
# time duration = 41.843, best val acc = 0.900, test acc = 0.910
# time duration = 49.304, best val acc = 0.898, test acc = 0.905
# time duration = 37.809, best val acc = 0.896, test acc = 0.911
# time duration = 45.496, best val acc = 0.900, test acc = 0.904
# time duration = 41.023, best val acc = 0.900, test acc = 0.906
# time duration = 40.610, best val acc = 0.900, test acc = 0.912
# time duration = 70.110, best val acc = 0.898, test acc = 0.909
# time duration = 67.765, best val acc = 0.891, test acc = 0.902
# time duration = 55.574, best val acc = 0.898, test acc = 0.906
# time duration = 64.951, best val acc = 0.902, test acc = 0.911
# time duration = 45.493, best val acc = 0.893, test acc = 0.908
# time duration = 36.320, best val acc = 0.898, test acc = 0.904
# time duration = 101.931, best val acc = 0.900, test acc = 0.905
# time duration = 43.234, best val acc = 0.900, test acc = 0.910
# time duration = 38.539, best val acc = 0.896, test acc = 0.906
# time duration = 41.241, best val acc = 0.900, test acc = 0.911
# time duration = 73.581, best val acc = 0.898, test acc = 0.895
# time duration = 40.408, best val acc = 0.902, test acc = 0.909
# time duration = 40.393, best val acc = 0.900, test acc = 0.908
# time duration = 38.546, best val acc = 0.889, test acc = 0.909
# time duration = 38.915, best val acc = 0.896, test acc = 0.911
# time duration = 41.927, best val acc = 0.898, test acc = 0.907
# test acc (mean, std):  0.907577387491862 0.004203610575159027
# test acc (mean, std) after filter:  0.9080859273672104 0.0024789519739487425

# %%
accs = np.array(accs)
np.savetxt('acc_TreeLSTM_hop10.txt',accs)
