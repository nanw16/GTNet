# %%
class config:
    data = 'Cora' #choices=["Cora", "Citeseer", "Pubmed", "Coauthor-CS"]
    model = 'GTAN' #choices=["GCN", "GAT", "APPNP", "DAGNN", "TreeLSTM", "GTCN", "GTAN", "GTCN2"]
    n_hid = 64
    dropout = 0.6
    dropout2 = 0.6
    learning_rate = 0.01
    weight_decay = 5e-4
    patience = 300
    num_iter = 1000
    num_test = 30
    hop = 2
    layerwise = True
    zero_init = False
    random_label_split = False
    num_train = 20 # for random label split only
    num_val = 30 # for random label split only
    data_load = True # load the saved label split to rerun the test (for reproduce purpose)
    test_id = 1 # number of the test, only used to record the ith number of the random label split (for reproduce purpose)
    filter_pct = 0.1 # remove the top and bottom filer_pct points before obtaining statistics of test accuracy
    log = False # whether to show the training log or not
    eval_metric = 'acc' # evaluation metrics, choices=["acc", "f1-macro", "f1-micro"]
    root_dir = '../..' # dir of the source code

args = config()

# %%
import sys
sys.path.append(args.root_dir)
from train import *
# Out:
# Using backend: pytorch

# %%
accs = []
datasets = ['Cora', 'Citeseer', 'Pubmed', 'Coauthor-CS']
for dataset in datasets:
    args.data = dataset
    if dataset == 'Cora':
        args.dropout = 0.6
        args.dropout2 = 0.6
        args.zero_init = False
        args.weight_decay = 5e-4
        print('\nstart testing on ' + dataset + ' dataset')
        accs.append(main(args))
    elif dataset == 'Citeseer':
        args.dropout = 0.6
        args.dropout2 = 0.6
        args.zero_init = True
        args.weight_decay = 5e-4
        print('\nstart testing on ' + dataset + ' dataset')
        accs.append(main(args))
    elif dataset == 'Pubmed':
        args.dropout = 0.6
        args.dropout2 = 0
        args.zero_init = False
        args.weight_decay = 5e-4
        print('\nstart testing on ' + dataset + ' dataset')
        accs.append(main(args))
    elif dataset == 'Coauthor-CS':
        args.dropout = 0.2
        args.dropout2 = 0.2
        args.weight_decay = 5e-3
        args.layerwise = False
        args.zero_init = True
        for i in [2]:
            print('\nstart testing on ' + dataset + ' dataset with random split: ' + str(i))
            args.test_id = i
            accs.append(main(args))
# Out:
# start testing on Cora dataset
#   NumNodes: 2708
#   NumEdges: 10556
#   NumFeats: 1433
#   NumClasses: 7
#   NumTrainingSamples: 140
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# time duration = 6.885, best val acc = 0.820, test acc = 0.829
# time duration = 3.535, best val acc = 0.824, test acc = 0.831
# time duration = 5.152, best val acc = 0.820, test acc = 0.827
# time duration = 5.939, best val acc = 0.824, test acc = 0.814
# time duration = 2.267, best val acc = 0.830, test acc = 0.836
# time duration = 2.763, best val acc = 0.824, test acc = 0.828
# time duration = 2.519, best val acc = 0.814, test acc = 0.826
# time duration = 3.356, best val acc = 0.820, test acc = 0.827
# time duration = 3.093, best val acc = 0.834, test acc = 0.825
# time duration = 2.913, best val acc = 0.822, test acc = 0.833
# time duration = 2.976, best val acc = 0.822, test acc = 0.834
# time duration = 4.366, best val acc = 0.816, test acc = 0.833
# time duration = 2.945, best val acc = 0.826, test acc = 0.827
# time duration = 3.108, best val acc = 0.822, test acc = 0.828
# time duration = 2.492, best val acc = 0.818, test acc = 0.830
# time duration = 3.126, best val acc = 0.820, test acc = 0.836
# time duration = 4.336, best val acc = 0.824, test acc = 0.826
# time duration = 3.617, best val acc = 0.820, test acc = 0.819
# time duration = 3.662, best val acc = 0.818, test acc = 0.822
# time duration = 3.327, best val acc = 0.824, test acc = 0.834
# time duration = 5.299, best val acc = 0.818, test acc = 0.828
# time duration = 2.854, best val acc = 0.828, test acc = 0.832
# time duration = 3.003, best val acc = 0.820, test acc = 0.833
# time duration = 3.948, best val acc = 0.826, test acc = 0.834
# time duration = 3.140, best val acc = 0.822, test acc = 0.833
# time duration = 4.246, best val acc = 0.828, test acc = 0.829
# time duration = 2.879, best val acc = 0.816, test acc = 0.835
# time duration = 2.711, best val acc = 0.830, test acc = 0.833
# time duration = 3.289, best val acc = 0.832, test acc = 0.833
# time duration = 2.903, best val acc = 0.832, test acc = 0.843
# test acc (mean, std):  0.8299333790938059 0.00551322116592297
# test acc (mean, std) after filter:  0.8303333818912506 0.0030777028478428873
#
# start testing on Citeseer dataset
#   NumNodes: 3327
#   NumEdges: 9228
#   NumFeats: 3703
#   NumClasses: 6
#   NumTrainingSamples: 120
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# time duration = 2.597, best val acc = 0.730, test acc = 0.717
# time duration = 2.495, best val acc = 0.726, test acc = 0.699
# time duration = 2.478, best val acc = 0.734, test acc = 0.686
# time duration = 2.622, best val acc = 0.742, test acc = 0.697
# time duration = 2.605, best val acc = 0.726, test acc = 0.710
# time duration = 2.439, best val acc = 0.732, test acc = 0.713
# time duration = 2.445, best val acc = 0.722, test acc = 0.729
# time duration = 2.400, best val acc = 0.734, test acc = 0.713
# time duration = 2.407, best val acc = 0.732, test acc = 0.705
# time duration = 2.497, best val acc = 0.740, test acc = 0.717
# time duration = 2.647, best val acc = 0.722, test acc = 0.715
# time duration = 2.535, best val acc = 0.728, test acc = 0.716
# time duration = 2.481, best val acc = 0.736, test acc = 0.717
# time duration = 2.641, best val acc = 0.730, test acc = 0.724
# time duration = 2.519, best val acc = 0.722, test acc = 0.717
# time duration = 3.300, best val acc = 0.730, test acc = 0.718
# time duration = 2.495, best val acc = 0.732, test acc = 0.705
# time duration = 2.281, best val acc = 0.730, test acc = 0.700
# time duration = 2.401, best val acc = 0.732, test acc = 0.721
# time duration = 2.945, best val acc = 0.730, test acc = 0.694
# time duration = 2.590, best val acc = 0.740, test acc = 0.709
# time duration = 2.554, best val acc = 0.740, test acc = 0.724
# time duration = 2.427, best val acc = 0.734, test acc = 0.713
# time duration = 2.571, best val acc = 0.714, test acc = 0.706
# time duration = 2.586, best val acc = 0.720, test acc = 0.718
# time duration = 2.697, best val acc = 0.728, test acc = 0.709
# time duration = 2.368, best val acc = 0.732, test acc = 0.715
# time duration = 2.407, best val acc = 0.728, test acc = 0.710
# time duration = 2.536, best val acc = 0.730, test acc = 0.724
# time duration = 3.162, best val acc = 0.724, test acc = 0.720
# test acc (mean, std):  0.7120333691438039 0.009614164611872339
# test acc (mean, std) after filter:  0.7127917036414146 0.006311219775018526
#
# start testing on Pubmed dataset
#   NumNodes: 19717
#   NumEdges: 88651
#   NumFeats: 500
#   NumClasses: 3
#   NumTrainingSamples: 60
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.
# time duration = 4.455, best val acc = 0.812, test acc = 0.792
# time duration = 5.100, best val acc = 0.822, test acc = 0.799
# time duration = 6.642, best val acc = 0.822, test acc = 0.794
# time duration = 5.894, best val acc = 0.826, test acc = 0.801
# time duration = 6.128, best val acc = 0.828, test acc = 0.801
# time duration = 4.054, best val acc = 0.816, test acc = 0.792
# time duration = 8.764, best val acc = 0.818, test acc = 0.792
# time duration = 3.676, best val acc = 0.812, test acc = 0.790
# time duration = 4.766, best val acc = 0.808, test acc = 0.790
# time duration = 6.801, best val acc = 0.824, test acc = 0.792
# time duration = 6.913, best val acc = 0.826, test acc = 0.785
# time duration = 6.337, best val acc = 0.820, test acc = 0.782
# time duration = 4.514, best val acc = 0.818, test acc = 0.793
# time duration = 4.832, best val acc = 0.818, test acc = 0.781
# time duration = 5.960, best val acc = 0.816, test acc = 0.803
# time duration = 5.031, best val acc = 0.824, test acc = 0.798
# time duration = 4.293, best val acc = 0.818, test acc = 0.774
# time duration = 4.792, best val acc = 0.828, test acc = 0.782
# time duration = 5.737, best val acc = 0.822, test acc = 0.776
# time duration = 6.892, best val acc = 0.814, test acc = 0.786
# time duration = 5.178, best val acc = 0.822, test acc = 0.805
# time duration = 7.194, best val acc = 0.830, test acc = 0.786
# time duration = 5.728, best val acc = 0.826, test acc = 0.796
# time duration = 3.991, best val acc = 0.818, test acc = 0.786
# time duration = 6.220, best val acc = 0.820, test acc = 0.780
# time duration = 4.774, best val acc = 0.816, test acc = 0.794
# time duration = 4.312, best val acc = 0.818, test acc = 0.794
# time duration = 4.671, best val acc = 0.808, test acc = 0.778
# time duration = 3.925, best val acc = 0.816, test acc = 0.805
# time duration = 6.241, best val acc = 0.820, test acc = 0.784
# test acc (mean, std):  0.7903667072455088 0.008416193206066708
# test acc (mean, std) after filter:  0.7904167051116625 0.006157091883852851
#
# start testing on Coauthor-CS dataset with random split: 2
# time duration = 11.147, best val acc = 0.904, test acc = 0.920
# time duration = 14.286, best val acc = 0.916, test acc = 0.911
# time duration = 18.519, best val acc = 0.916, test acc = 0.924
# time duration = 9.287, best val acc = 0.918, test acc = 0.912
# time duration = 11.360, best val acc = 0.922, test acc = 0.920
# time duration = 7.602, best val acc = 0.913, test acc = 0.911
# time duration = 13.337, best val acc = 0.911, test acc = 0.919
# time duration = 7.616, best val acc = 0.909, test acc = 0.915
# time duration = 10.474, best val acc = 0.911, test acc = 0.913
# time duration = 12.173, best val acc = 0.911, test acc = 0.913
# time duration = 7.879, best val acc = 0.913, test acc = 0.914
# time duration = 7.670, best val acc = 0.907, test acc = 0.913
# time duration = 10.619, best val acc = 0.918, test acc = 0.920
# time duration = 8.221, best val acc = 0.918, test acc = 0.918
# time duration = 11.993, best val acc = 0.916, test acc = 0.916
# time duration = 11.849, best val acc = 0.913, test acc = 0.915
# time duration = 12.588, best val acc = 0.913, test acc = 0.918
# time duration = 14.196, best val acc = 0.909, test acc = 0.916
# time duration = 7.978, best val acc = 0.911, test acc = 0.915
# time duration = 7.990, best val acc = 0.920, test acc = 0.919
# time duration = 7.744, best val acc = 0.907, test acc = 0.912
# time duration = 13.248, best val acc = 0.924, test acc = 0.921
# time duration = 7.813, best val acc = 0.911, test acc = 0.919
# time duration = 9.026, best val acc = 0.909, test acc = 0.914
# time duration = 10.410, best val acc = 0.913, test acc = 0.919
# time duration = 7.874, best val acc = 0.918, test acc = 0.915
# time duration = 8.947, best val acc = 0.913, test acc = 0.913
# time duration = 8.476, best val acc = 0.918, test acc = 0.920
# time duration = 7.877, best val acc = 0.916, test acc = 0.919
# time duration = 7.923, best val acc = 0.916, test acc = 0.916
# test acc (mean, std):  0.9162751773993174 0.003263339669946828
# test acc (mean, std) after filter:  0.9162424728274345 0.002521809704532186

# %%
accs = np.array(accs)
